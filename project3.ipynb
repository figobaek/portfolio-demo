# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
pd.set_option("display.max_rows", 1000) 
pd.set_option("display.max_columns", 100)

# %%
df = pd.read_csv('/Users/figobaek/Desktop/objective/itwill/project/project3/dfmine.csv', index_col=[0])

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   제목              100 non-null    object
#  1   저자              100 non-null    object
#  2   성별(범주)          100 non-null    object
#  3   출판사             100 non-null    object
#  4   출판일(초판)(년, 월로)  100 non-null    int64
#  5   출판월             100 non-null    int64
#  6   가격              100 non-null    int64
#  7   책 형태(전자 or 종이)  100 non-null    object
#  8   세일즈포인트          100 non-null    int64
#  9   평점(반올림, 범주)     100 non-null    float64
#  10  리뷰+100자평 갯수     100 non-null    int64
#  11  전체쪽수            100 non-null    int64
#  12  무게(g)           100 non-null    int64
#  13  장르(범주, 알라딘)     100 non-null    object
#  14  구매년도            100 non-null    int64
#  15  구매 월            100 non-null    int64
#  16  구매 계절           100 non-null    object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0             제목       저자  성별(범주)     출판사   출판일(초판)(년, 월로)  출판월  \
# 0           0     당신 인생의 이야기      테드 창      남       엘리            2016   10
# 1           1  빅데이터를 지탱하는 기술  니시다 케이스케      남     jpub            2018   11
# 2           2          런던스케치     도리스레싱      여      민음사            2003    8
# 3           3    3개월안에유창해지는법     베니루이스      남  알키(시공사)            2014   11
# 4           4         태도에관하여       임경선      여    한겨레출판            2015    3
#
#       가격 책 형태(전자 or 종이)  세일즈포인트  평점(반올림, 범주)  리뷰+100자평 갯수  전체쪽수  무게(g)  \
# 0  13050              p   36663          8.8          175   446    565
# 1  24300              p     928          8.0            1   286    593
# 2   9000              p    1736          7.6           33   306    581
# 3  11700              p     243          8.6           18   335    480
# 4  12420              p   10804          8.0           23   310    395
#
#   장르(범주, 알라딘)  구매년도  구매 월 구매 계절 구매경로(범주) 완독여부
# ...

# %%
df['출판월'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['구매 계절'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.info()
df['완독여부'].value_counts()
df['comp'] = df['완독여부'].map({'yes':1, 'no':0})
df['btype'] = df['책 형태(전자 or 종이)'].map({'p':1, 'e':0})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   제목              100 non-null    object
#  1   저자              100 non-null    object
#  2   성별(범주)          100 non-null    object
#  3   출판사             100 non-null    object
#  4   출판일(초판)(년, 월로)  100 non-null    int64
#  5   출판월             100 non-null    int64
#  6   가격              100 non-null    int64
#  7   책 형태(전자 or 종이)  100 non-null    object
#  8   세일즈포인트          100 non-null    int64
#  9   평점(반올림, 범주)     100 non-null    float64
#  10  리뷰+100자평 갯수     100 non-null    int64
#  11  전체쪽수            100 non-null    int64
#  12  무게(g)           100 non-null    int64
#  13  장르(범주, 알라딘)     100 non-null    object
#  14  구매년도            100 non-null    int64
#  15  구매 월            100 non-null    int64
#  16  구매 계절           100 non-null    object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   제목              100 non-null    object
#  1   저자              100 non-null    object
#  2   성별(범주)          100 non-null    object
#  3   출판사             100 non-null    object
#  4   출판일(초판)(년, 월로)  100 non-null    int64
#  5   출판월             100 non-null    int64
#  6   가격              100 non-null    int64
#  7   책 형태(전자 or 종이)  100 non-null    object
#  8   세일즈포인트          100 non-null    int64
#  9   평점(반올림, 범주)     100 non-null    float64
#  10  리뷰+100자평 갯수     100 non-null    int64
#  11  전체쪽수            100 non-null    int64
#  12  무게(g)           100 non-null    int64
#  13  장르(범주, 알라딘)     100 non-null    object
#  14  구매년도            100 non-null    int64
#  15  구매 월            100 non-null    int64
#  16  구매 계절           100 non-null    object
# ...

# %%
df.head()
# Out:
#               제목       저자  성별(범주)     출판사   출판일(초판)(년, 월로)  출판월     가격  \
# 0     당신 인생의 이야기      테드 창      남       엘리            2016   10  13050
# 1  빅데이터를 지탱하는 기술  니시다 케이스케      남     jpub            2018   11  24300
# 2          런던스케치     도리스레싱      여      민음사            2003    8   9000
# 3    3개월안에유창해지는법     베니루이스      남  알키(시공사)            2014   11  11700
# 4         태도에관하여       임경선      여    한겨레출판            2015    3  12420
#
#   책 형태(전자 or 종이)  세일즈포인트  평점(반올림, 범주)  리뷰+100자평 갯수  전체쪽수  무게(g) 장르(범주, 알라딘)  \
# 0              p   36663          8.8          175   446    565        과학소설
# 1              p     928          8.0            1   286    593    데이터베이스구축
# 2              p    1736          7.6           33   306    581        영국문학
# 3              p     243          8.6           18   335    480       영어학습법
# 4              p   10804          8.0           23   310    395       한국에세이
#
#    구매년도  구매 월 구매 계절 구매경로(범주) 완독여부  comp  btype
# ...

# %%
df['성별(범주)'] = df['성별(범주)'].astype('category')

# %%
df.columns = ['title', 'author', 'sex', 'pub', 'pubd', 'pubm', 'price',
       'type', 'salesp', 'point', 'review100', 'pages',
       'weight', 'genre', 'buyy', 'buym', 'buys', 'buyr', 'clear',
       'comp', 'btype']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      100 non-null    object
#  1   author     100 non-null    object
#  2   sex        100 non-null    category
#  3   pub        100 non-null    object
#  4   pubd       100 non-null    int64
#  5   pubm       100 non-null    int64
#  6   price      100 non-null    int64
#  7   type       100 non-null    object
#  8   salesp     100 non-null    int64
#  9   point      100 non-null    float64
#  10  review100  100 non-null    int64
#  11  pages      100 non-null    int64
#  12  weight     100 non-null    int64
#  13  genre      100 non-null    object
#  14  buyy       100 non-null    int64
#  15  buym       100 non-null    int64
#  16  buys       100 non-null    object
#  17  buyr       100 non-null    object
#  18  clear      100 non-null    object
# ...

# %%
df.to_csv("df0107.csv", index=False)

# %%
pd.read_csv("df0107.csv")
# Out:
#                        title      author sex                   pub  pubd  \
# 0                 당신 인생의 이야기        테드 창   남                    엘리  2016
# 1              빅데이터를 지탱하는 기술    니시다 케이스케   남                  jpub  2018
# 2                      런던스케치       도리스레싱   여                   민음사  2003
# 3                3개월안에유창해지는법       베니루이스   남               알키(시공사)  2014
# 4                     태도에관하여         임경선   여                 한겨레출판  2015
# 5                직장인에서 직업인으로          김호   남                   김영사  2020
# 6         문과생, 데이터 사이언티스트 되다         차현나   여                  더퀘스트  2020
# 7               20 vs 80의 사회     리처드 리브스   남                   민음사  2019
# 8      숫자에 약한 사람들을 위한 통계학 수업  데이비드 스피겔할터   남               웅진지식하우스  2020
# 9                   gv빌런 고태경         정대건   남                  은행나무  2020
# 10                 지구에 대한 의무         가디언  공동                 스리체어스  2019
# 11        Digital minimalism       칼 뉴포트   남  penguin\nrandomhouse  2019
# ...

# %%
df['성별(범주)']
# Out:
# 0      남
# 1      남
# 2      여
# 3      남
# 4      여
# 5      남
# 6      여
# 7      남
# 8      남
# 9      남
# 10    공동
# 11     남
# 12     여
# 13     여
# 14    공동
# 15     남
# 16     남
# 17    공동
# 18     여
# 19     여
# 20     여
# 21     남
# 22     남
# 23    공동
# 24     여
# 25     여
# 26     여
# 27     남
# 28     여
# 29     남
# 30     남
# 31     여
# 32     여
# 33     남
# 34    공동
# 35     여
# 36     남
# 37     남
# 38     여
# 39     남
# 40     남
# 41     여
# 42     여
# 43     여
# 44     여
# 45     여
# 46     남
# 47     남
# 48     여
# 49     여
# 50     여
# 51     남
# 52     여
# 53     여
# 54     남
# 55     여
# 56     남
# 57    공동
# 58     여
# 59     여
# 60     남
# 61     남
# 62     여
# 63     남
# 64     남
# 65     남
# 66     남
# 67     남
# 68     남
# 69     남
# 70     남
# 71    공동
# 72     여
# 73     남
# 74     여
# 75     남
# 76     남
# 77     남
# 78     남
# 79     남
# 80     남
# 81     남
# 82     여
# 83     남
# 84     남
# 85     여
# 86     여
# 87    공동
# 88     남
# 89     남
# ...
